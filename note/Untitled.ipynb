# %%
import pandas as pd

# %%
path = '~/data/movies/dailyboxoffice/dt=20240101'
df = pd.read_parquet(path)
len(df)
# Out:
# 50

# %%
df.groupby(['multiMovieYn', 'repNationCd'], dropna=False, observed=False).size().reset_index(name='count')
# Out:
#   multiMovieYn repNationCd  count
# 0            N           F      0
# 1            N           K      0
# 2            N         NaN     10
# 3            Y           F      0
# 4            Y           K      0
# 5            Y         NaN     10
# 6          NaN           F     10
# 7          NaN           K     10
# 8          NaN         NaN     10

# %%
df.head(5)
# Out:
#    rnum  rank  rankInten rankOldAndNew   movieCd  \
# 0     1     1          0           OLD  20203702
# 1     2     2          0           OLD  20212866
# 2     3     3          0           OLD  20236146
# 3     4     4          0           OLD  20235735
# 4     5     5          0           OLD  20235596
#
#                                 movieNm      openDt    salesAmt  salesShare  \
# 0                            노량: 죽음의 바다  2023-12-20  2893509165        38.8
# 1                                 서울의 봄  2023-11-22  2666429137        35.8
# 2  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  2023-12-22   565417320         7.6
# 3                          아쿠아맨과 로스트 킹덤  2023-12-20   507984981         6.8
# 4                            트롤: 밴드 투게더  2023-12-20   273538754         3.7
#
#    salesInten  salesChange      salesAcc  audiCnt  audiInten  audiChange  \
# 0  -686119312        -19.2   36926118105   290717     -59184       -16.9
# ...

# %%
df[df['movieCd'] == '20203702']
# Out:
#     rnum  rank  rankInten rankOldAndNew   movieCd     movieNm      openDt  \
# 0      1     1          0           OLD  20203702  노량: 죽음의 바다  2023-12-20
# 10     1     1          0           OLD  20203702  노량: 죽음의 바다  2023-12-20
# 40     1     1          0           OLD  20203702  노량: 죽음의 바다  2023-12-20
#
#       salesAmt  salesShare  salesInten  salesChange     salesAcc  audiCnt  \
# 0   2893509165        38.8  -686119312        -19.2  36926118105   290717
# 10  2893509165        40.2  -686119312        -19.2  36926118105   290717
# 40  2893509165        49.8  -686119312        -19.2  36926118105   290717
#
#     audiInten  audiChange  audiAcc  scrnCnt  showCnt multiMovieYn repNationCd
# 0      -59184       -16.9  3728850     1706     5793          NaN         NaN
# 10     -59184       -16.9  3728850     1706     5793            N         NaN
# 40     -59184       -16.9  3728850     1706     5793          NaN           K

# %%
df = df[['rnum', 'rank', 'movieCd', 'movieNm', 'openDt', 'salesAmt', 'multiMovieYn', 'repNationCd']]

# %%
df
# Out:
#     rnum  rank   movieCd                               movieNm      openDt  \
# 0      1     1  20203702                            노량: 죽음의 바다  2023-12-20
# 1      2     2  20212866                                 서울의 봄  2023-11-22
# 2      3     3  20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  2023-12-22
# 3      4     4  20235735                          아쿠아맨과 로스트 킹덤  2023-12-20
# 4      5     5  20235596                            트롤: 밴드 투게더  2023-12-20
# 5      6     6  20234673                      뽀로로 극장판 슈퍼스타 대모험  2023-12-13
# 6      7     7  20235290                             도티와 영원의 탑  2023-12-27
# 7      8     8  20234114                                    괴물  2023-11-29
# 8      9     9  20236045  바다 탐험대 옥토넛 어보브 앤 비욘드: 버드, 옥토경보를 울려라!  2023-12-27
# 9     10    10  20235980                             말하고 싶은 비밀  2023-12-13
# 10     1     1  20203702                            노량: 죽음의 바다  2023-12-20
# ...
